# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmiyasubramaniam/MyWorks/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()

df = pd.read_csv('heart_attack_prediction_india (2).csv')
# Out:
#      <input type="file" id="files-50d87c43-dcda-499f-932b-5c304e4ed088" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50d87c43-dcda-499f-932b-5c304e4ed088">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                7000 non-null   int64
#  1   Gender                             7000 non-null   int64
#  2   Chest Pain Type                    7000 non-null   int64
#  3   Resting Blood Pressure             7000 non-null   int64
#  4   Cholesterol                        7000 non-null   int64
#  5   Fasting Blood Sugar (> 120 mg/dL)  7000 non-null   int64
#  6   Resting ECG Results                7000 non-null   int64
#  7   Max Heart Rate Achieved            7000 non-null   int64
#  8   Exercise-Induced Angina            7000 non-null   int64
#  9   Old Peak (ST Depression)           7000 non-null   float64
#  10  Slope of Peak Exercise ST Segment  7000 non-null   int64
# ...

# %%
df.head()
# Out:
#    Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0   69       0                4                     109          487
# 1   32       0                2                     125          170
# 2   89       0                2                     186          543
# 3   78       0                2                     104          367
# 4   38       1                1                     151          158
#
#    Fasting Blood Sugar (> 120 mg/dL)  Resting ECG Results  \
# 0                                  1                    1
# 1                                  0                    1
# 2                                  1                    0
# 3                                  0                    0
# 4                                  1                    0
#
#    Max Heart Rate Achieved  Exercise-Induced Angina  Old Peak (ST Depression)  \
# 0                      122                        1                      3.51
# ...

# %%
df.describe()
# Out:
#                Age       Gender  Chest Pain Type  Resting Blood Pressure  \
# count  7000.000000  7000.000000      7000.000000             7000.000000
# mean     58.227857     0.492571         2.507857              144.207857
# std      23.511403     0.499981         1.119491               31.682105
# min      18.000000     0.000000         1.000000               90.000000
# 25%      38.000000     0.000000         2.000000              117.000000
# 50%      58.000000     0.000000         3.000000              144.000000
# 75%      78.000000     1.000000         4.000000              172.000000
# max      99.000000     1.000000         4.000000              199.000000
#
#        Cholesterol  Fasting Blood Sugar (> 120 mg/dL)  Resting ECG Results  \
# count  7000.000000                        7000.000000          7000.000000
# mean    351.351000                           0.492429             0.489571
# std     146.303141                           0.499978             0.499927
# ...

# %%
df.dtypes
# Out:
# Age                                    int64
# Gender                                 int64
# Chest Pain Type                        int64
# Resting Blood Pressure                 int64
# Cholesterol                            int64
# Fasting Blood Sugar (> 120 mg/dL)      int64
# Resting ECG Results                    int64
# Max Heart Rate Achieved                int64
# Exercise-Induced Angina                int64
# Old Peak (ST Depression)             float64
# Slope of Peak Exercise ST Segment      int64
# Number of Major Vessels (0-3)          int64
# Thalassemia                            int64
# Smoking History                        int64
# Obesity (BMI > 30)                     int64
# Hypertension History                   int64
# Diabetes History                       int64
# Alcohol Consumption                    int64
# Physical Activity                      int64
# Stress Levels                          int64
# Family History of Heart Disease        int64
# ...

# %%
df.nunique()
# Out:
# Age                                   82
# Gender                                 2
# Chest Pain Type                        4
# Resting Blood Pressure               110
# Cholesterol                          500
# Fasting Blood Sugar (> 120 mg/dL)      2
# Resting ECG Results                    2
# Max Heart Rate Achieved              150
# Exercise-Induced Angina                2
# Old Peak (ST Depression)             601
# Slope of Peak Exercise ST Segment      3
# Number of Major Vessels (0-3)          4
# Thalassemia                            3
# Smoking History                        2
# Obesity (BMI > 30)                     2
# Hypertension History                   2
# Diabetes History                       2
# Alcohol Consumption                    2
# Physical Activity                      2
# Stress Levels                          3
# Family History of Heart Disease        2
# Heart Attack Risk                      2
# dtype: int64

# %% [markdown]
# | Column Name                       | Description                                   | Data Type   | Values / Range                                                              |
# | --------------------------------- | --------------------------------------------- | ----------- | --------------------------------------------------------------------------- |
# | Age                               | Age of the individual                         | Numerical   | 18 to 100                                                                   |
# | Gender                            | Gender (0 = Female, 1 = Male)                 | Binary      | 0, 1                                                                        |
# | Chest Pain Type                   | Type of chest pain                            | Categorical | 1: Typical Angina, 2: Atypical Angina, 3: Non-anginal Pain, 4: Asymptomatic |
# | Resting Blood Pressure            | Resting blood pressure (mm Hg)                | Numerical   | 90 to 200                                                                   |
# | Cholesterol                       | Serum cholesterol (mg/dL)                     | Numerical   | 100 to 600                                                                  |
# | Fasting Blood Sugar (> 120 mg/dL) | FBS > 120 mg/dL                               | Binary      | 0: No, 1: Yes                                                               |
# | Resting ECG Results               | ECG at rest                                   | Categorical | 0: Normal, 1: Abnormal                                                      |
# | Max Heart Rate Achieved           | Maximum heart rate during exercise            | Numerical   | 70 to 220                                                                   |
# | Exercise-Induced Angina           | Angina caused by exercise                     | Binary      | 0: No, 1: Yes                                                               |
# | Old Peak (ST Depression)          | ST depression induced by exercise             | Numerical   | 0.0 to 6.0                                                                  |
# | Slope of Peak Exercise ST Segment | Slope of the ST segment                       | Categorical | 1: Upsloping, 2: Flat, 3: Downsloping                                       |
# | Number of Major Vessels (0–3)     | Count of major vessels colored by fluoroscopy | Categorical | 0, 1, 2, 3                                                                  |
# | Thalassemia                       | Blood disorder type                           | Categorical | 1: Normal, 2: Fixed Defect, 3: Reversible Defect                            |
# | Smoking History                   | History of smoking                            | Binary      | 0: No, 1: Yes                                                               |
# | Obesity (BMI > 30)                | Obesity indicator                             | Binary      | 0: No, 1: Yes                                                               |
# | Hypertension History              | History of high blood pressure                | Binary      | 0: No, 1: Yes                                                               |
# | Diabetes History                  | History of diabetes                           | Binary      | 0: No, 1: Yes                                                               |
# | Alcohol Consumption               | Alcohol usage history                         | Binary      | 0: No, 1: Yes                                                               |
# | Physical Activity                 | Activity level                                | Binary      | 0: Sedentary, 1: Active                                                     |
# | Stress Levels                     | Level of stress                               | Categorical | 1: Low, 2: Medium, 3: High                                                  |
# | Family History of Heart Disease   | Hereditary heart disease risk                 | Binary      | 0: No, 1: Yes                                                               |
# | Heart Attack Risk (Target)        | Risk of heart attack                          | Binary      | 0: Low Risk, 1: High Risk                                                   |
